# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarade/Hindi-Toxic-Comment-Classification-Using-BERT-Embeddings/blob/main/Hindi_Toxic%C2%A0Comment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install --upgrade pandas tensorflow_gpu ktrain
! rm -rf apex
! git clone https://www.github.com/nvidia/apex
! cd apex && python setup.py install

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from transformers import BertTokenizer
from transformers import AutoTokenizer
import tensorflow as tf
import numpy as np
import pandas as pd

# %% [markdown]
# **Loading data**

# %%
import pandas as pd 

df = pd.read_csv("/hi_3500.csv", header=0, names=['review', 'sentiment'])
print(df.head())
# Out:
#                                               review sentiment
# 0  गुमनाम है वतन पर मिटने वाले लोग आतन्कवादियों स...  negative
# 1  ज़ंजीर बदली जा रही थी मैं समझा था रिहाई हो गयी है  negative
# 2  यूपी में बड़े स्तर पर दंगे करवा सकती है बीजेपी...  negative
# 3  अंग्रेजी नहीं आती है इसलिए हिन्दी ट्विट ज्यादा...  negative
# 4                    कश्मीर में हो रहा है जल जिहाद ।  negative

# %% [markdown]
# **Converting three class to two class**

# %%
hui=[]
for i in df.sentiment.values:
  if i =='negative':
    hui.append(1)
  else:
    hui.append(0)
df=df.drop(columns='sentiment')
df['sentiment']=hui

# %% [markdown]
# **Data pre-processing**

# %%
def preprocess(text):
    new_text = []
    for i in text.split(" "):
        i= '' if i.startswith('@') and len(i) > 1 else i
        i = '' if i.startswith('http') else i
        i = i.replace("#","")
        new_text.append(i)
    return " ".join(new_text).strip().replace("  ", " ")

# %%
df['review']=df.review.apply(preprocess)

# %%
df.head()
# Out:
#                                               review  sentiment
# 0  गुमनाम है वतन पर मिटने वाले लोग आतन्कवादियों स...          1
# 1  ज़ंजीर बदली जा रही थी मैं समझा था रिहाई हो गयी है          1
# 2  यूपी में बड़े स्तर पर दंगे करवा सकती है बीजेपी...          1
# 3  अंग्रेजी नहीं आती है इसलिए हिन्दी ट्विट ज्यादा...          1
# 4                    कश्मीर में हो रहा है जल जिहाद ।          1

# %% [markdown]
# **Converting text into Bert Tokenizer**

# %%
from transformers import BertTokenizer
from transformers import AutoTokenizer
from tqdm import tqdm
tokenizer = BertTokenizer.from_pretrained('google/muril-large-cased', do_lower_case=True)
# Out:
# Downloading:   0%|          | 0.00/3.02M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/406 [00:00<?, ?B/s]

# %%
new=df.review.values
newdf=[]
for i in tqdm(new):
  tokenizer = BertTokenizer.from_pretrained('google/muril-large-cased', do_lower_case=True)
  i2= tokenizer(i)
  i3=i2['input_ids']
#we do padding also. 60 words max in one sentence
  out=[0 for i in range(60)]
  out[:len(i3)]=i3
  newdf.append(out)
# Out:
# 100%|██████████| 9076/9076 [2:39:52<00:00,  1.06s/it]

# %%
y_hat=df.sentiment.values
Xtrain=np.array(newdf)
y_hat=np.array(y_hat)

# %% [markdown]
# **Training RandomForest Model**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Xtrain, y_hat, random_state=91)
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
print(classification_report(clf.predict(X_test),y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83      1777
#            1       0.46      0.76      0.58       492
#
#     accuracy                           0.76      2269
#    macro avg       0.69      0.76      0.70      2269
# weighted avg       0.82      0.76      0.78      2269

# %% [markdown]
# **Deep Learning approach**

# %% [markdown]
# **I use  ktrain library is a lightweight wrapper for tf.keras in Tensor Flow 2. It is designed to make deep learning and AI more accessible and easier to apply for beginners and domain experts. this library has inbuilt text cleaner**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['review'], df['sentiment'], random_state=91)

# %%
import ktrain
from ktrain import text
t = text.Transformer("monsoon-nlp/hindi-bert", maxlen=500, class_names=list(set(y_train.values)))
# Out:
# Downloading:   0%|          | 0.00/572 [00:00<?, ?B/s]

# %%
trn = t.preprocess_train(X_train.to_numpy(), y_train.to_numpy())
# Out:
# preprocessing train...
# language: hi
# train sequence lengths:
# 	mean : 16
# 	95percentile : 27
# 	99percentile : 30
# Downloading:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/593k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False

# %%
evalr = t.preprocess_test(X_test.to_numpy(), y_test.to_numpy())
# Out:
# preprocessing test...
# language: hi
# test sequence lengths:
# 	mean : 16
# 	95percentile : 27
# 	99percentile : 30
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
model = t.get_classifier()
# Out:
# Downloading:   0%|          | 0.00/56.4M [00:00<?, ?B/s]

# %% [markdown]
# **Training Model**

# %%
model = t.get_classifier()
learner = ktrain.get_learner(model, train_data=trn, val_data=evalr, batch_size=6)
learner.fit(1.2e-4, 5)
# Out:
# Epoch 1/5
# 1135/1135 [==============================] - 233s 186ms/step - loss: 0.5177 - accuracy: 0.7316 - val_loss: 0.4727 - val_accuracy: 0.7721
# Epoch 2/5
# 1135/1135 [==============================] - 205s 181ms/step - loss: 0.4189 - accuracy: 0.8193 - val_loss: 0.4397 - val_accuracy: 0.8017
# Epoch 3/5
# 1135/1135 [==============================] - 198s 175ms/step - loss: 0.3697 - accuracy: 0.8556 - val_loss: 0.4230 - val_accuracy: 0.8325
# Epoch 4/5
# 1135/1135 [==============================] - 199s 175ms/step - loss: 0.3019 - accuracy: 0.8955 - val_loss: 0.4241 - val_accuracy: 0.8352
# Epoch 5/5
# 1135/1135 [==============================] - 199s 175ms/step - loss: 0.2489 - accuracy: 0.9154 - val_loss: 0.3958 - val_accuracy: 0.8625

# %% [markdown]
# **Evaluation on Train Dataset**

# %%
model.explain("इन लोगो ने हमारे देश का नाम ख़राब किया हे,इन्हे जूते से मारना चाहिए🤬")
# Out:
# 1/1 [==============================] - 4s 4s/step
# 79/79 [==============================] - 4s 48ms/step
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=negative
#
# </b>
#
#
#     (probability <b>0.959</b>, score <b>-3.149</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.150
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.001
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 81.18%); opacity: 0.87" title="-0.581">इन</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.79%); opacity: 0.85" title="-0.389">ल</span><span style="opacity: 0.80">ो</span><span style="background-color: hsl(0, 100.00%, 82.94%); opacity: 0.86" title="-0.505">ग</span><span style="opacity: 0.80">ो </span><span style="background-color: hsl(120, 100.00%, 91.22%); opacity: 0.82" title="0.195">न</span><span style="opacity: 0.80">े </span><span style="background-color: hsl(120, 100.00%, 83.12%); opacity: 0.86" title="0.497">हम</span><span style="opacity: 0.80">ा</span><span style="background-color: hsl(120, 100.00%, 79.02%); opacity: 0.88" title="0.678">र</span><span style="opacity: 0.80">े </span><span style="background-color: hsl(120, 100.00%, 84.35%); opacity: 0.85" title="0.446">द</span><span style="opacity: 0.80">े</span><span style="background-color: hsl(0, 100.00%, 94.02%); opacity: 0.81" title="-0.113">श</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%,
span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 77.19%); opacity: 0.89" title="0.706">न</span><span style="opacity: 0.80">ा </span><span style="background-color: hsl(0, 100.00%, 93.02%); opacity: 0.82" title="-0.130">समझन</span><span style="opacity: 0.80">ा </span><span style="background-color: hsl(0, 100.00%, 90.74%); opacity: 0.82" title="-0.195">क</span><span style="opacity: 0.80">े </span><span style="background-color: hsl(120, 100.00%, 89.45%); opacity: 0.83" title="0.235">म</span><span style="opacity: 0.80">े</span><span style="background-color: hsl(120, 100.00%, 74.92%); opacity: 0.90" title="0.808">र</span><span style="opacity: 0.80">ी </span><span style="background-color: hsl(0, 100.00 ...
#     </p>

# %% [markdown]
# **failure cases**

# %%
model.explain('महाराष्ट्र में बड़े स्तर पर दंगे करवा सकती है बीजेपी')
# Out:
# 1/1 [==============================] - 0s 130ms/step
# 79/79 [==============================] - 5s 63ms/step
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.936</b>, score <b>2.675</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.284
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.609
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 84.45%); opacity: 0.85" title="-0.518">मह</span><span style="opacity: 0.80">ा</span><span style="background-color: hsl(0, 100.00%, 64.62%); opacity: 0.97" title="-1.677">र</span><span style="opacity: 0.80">ा</span><span style="background-color: hsl(0, 100.00%, 77.86%); opacity: 0.89" title="-0.858">ष</span><span style="opacity: 0.80">्</span><span style="background-color: hsl(0, 100.00%, 80.46%); opacity: 0.87" title="-0.718">ट</span><span style="opacity: 0.80">्</span><span style="background-color: hsl(120, 100.00%, 84.21%); opacity: 0.85" title="0.529">र</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.05%); opacity: 0.85" title="-0.537">म</span><span style="opacity: 0.80">ें </span><span style="background-color: hsl(120, 100.00%, 88.85%); opacity: 0.83" title="0.322">बड</span><span style="opacity: 0.80">़े </span><span style="background-color: hsl(120, 100.00%, 82.10%); opacity: 0.86" title="0.634">स</span><span style="opacity: 0.80">्</span><span style="background-color: hsl(120, 100.00%, 84.18%); opacity: 0.85" title="0.531">तर</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 82.48%); opacity: 0.86" title="-0.614">पर</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 74.17%); opacity: 0.91" title="1.070">द</span><span style="opacity: 0.80">ं</span><span style="background-color: hsl(0, 100.00%, 90.95%); opacity: 0.82" title="-0.239">ग</span><span style="opacity: 0.80">े </span><span style="background-color: hsl(120, 100.00%, 92.48%); opacity: 0.82" title="0.183">करव</span><span style="opacity: 0.80">ा </span><span style="background-color: hsl(120, 100.00%, 66.31%); opacity: 0.96" title="1.564">सकत</span><span style="opacity: 0.80">ी </span><span style="background-color: hsl(120, 100.00%, 90.48%); opacity: 0.83" title="0.257">ह</span><span style="opacity: 0.80">ै </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.998">ब</span><span style="opacity: 0.80">ी</span><span style="background-color: hsl(120, 100.00%, 87.45%); opacity: 0.84" title="0.382">ज</span><span style="opacity: 0.80">े</span><span style="background-color: hsl(0, 100.00%, 93.89%); opacity: 0.81" title="-0.137">प</span><span style="opacity: 0.80">ी</span>
#     </p>

# %%
model.explain('आगे से तुम ने फिर से ऐसे कपड़ों में फोटो डाला तो तुम्हारा बलात्कार कर देंगे')
# Out:
# 1/1 [==============================] - 0s 149ms/step
# 79/79 [==============================] - 4s 52ms/step
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y